# %% [markdown]
# # Assignment 3

# %% [markdown]
# Visualize the data using R/Python by plotting the graphs for assignment no. 1 and 2. Consider
# suitable data set. Use Scatter plot, Bar plot, Box plot, Pie chart, Line Chart.

# %%
#importing all the necessary libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the csv
df=pd.read_csv("D:/my documents\ML Clg Assignments\Assignment_3\Heart (1) - Heart (1).csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\adite\AppData\Local\Temp\ipykernel_7768\3858525861.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df=pd.read_csv("D:/my documents\ML Clg Assignments\Assignment_3\Heart (1) - Heart (1).csv")

# %%
#printing the 1st 5 rows of the dataset
df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
#to check if any column is having null values
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
#filling the null values with the mean
df["Ca"].fillna(df["Ca"].mean(), inplace=True)

# %%
#checking the unique values present in ChestPain column
df["ChestPain"].unique()
# Out:
# array(['typical', 'asymptomatic', 'nonanginal', 'nontypical'],
#       dtype=object)

# %%
#SCATTER PLOT

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

plt.figure(figsize=(8, 6))
sns.scatterplot(x="Age",y="MaxHR",hue="ChestPain",data=df,palette=["blue","green","yellow","red"])
plt.title("Scatter Plot")
plt.xlabel("Age")
plt.ylabel("MaxHR")
plt.show()

# %%
df["ChestPain"].value_counts()
# Out:
# ChestPain
# asymptomatic    144
# nonanginal       86
# nontypical       50
# typical          23
# Name: count, dtype: int64

# %%
#BAR CHART
import matplotlib.pyplot as plt  

df["ChestPain"].value_counts().plot(kind="bar", color="yellow")  
plt.title("Bar plot for ChestPain Frequency")  
plt.xlabel("ChestPain")  
plt.ylabel("Frequency")  
plt.show()

# %%
lables = df["Thal"].unique()
print(lables)
# Out:
# ['fixed' 'normal' 'reversable' nan]

# %%
lables = ['fixed', 'normal', 'reversable']

# %%
# PIE CHART
plt.pie(x=df["Thal"].value_counts(),labels=lables, autopct="%1.1f%%")
plt.title("Thallium Heart Scan Results")
plt.show()

# %%
#implementing box plot

plt.figure(figsize=(8,6))
sns.boxplot(y="Age",data=df,color="green")
plt.title("Box plot showing the range of people present in the dataset")
plt.show()

# %%
#Last 5 entries of the dataset
df.tail()
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope        Ca        Thal  AHD
# 298      0      1.2      2  0.000000  reversable  Yes
# 299      0      3.4      2  2.000000  reversable  Yes
# 300      1      1.2      2  1.000000  reversable  Yes
# 301      0      0.0      2  1.000000      normal  Yes
# 302      0      0.0      1  0.672241      normal   No

# %%
#implementing Line chart

plt.figure(figsize=(24,8))
sns.lineplot(x="Age",y="RestBP",data=df,marker="o",linestyle="-",color="red")
plt.title("Line chart: Age vs RestBP")
plt.xlabel("Age")
plt.ylabel("RestBP")
plt.grid(True)
plt.show()
